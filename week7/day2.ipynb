# %% [markdown]
# # Week 7 Day 2
#
# # "THE PRICE IS RIGHT" Capstone Project
#
# This week - fine tune an open-source model!
#
# A model that can estimate how much something costs, from its description.
#
# # Order of play
#
# DAY 1: QLoRA
# DAY 2: Prompt data and Base Model
# DAY 3: Train Part 1
# DAY 4: Train Part 2
# DAY 5: Eval
#
# ## First we need to upload the final dataset

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login
from pricer.items import Item
from tqdm.notebook import tqdm
from transformers import AutoTokenizer
import matplotlib.pyplot as plt

# %%
LITE_MODE = True

load_dotenv(override=True)
hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
username = "ed-donner"
dataset = f"{username}/items_lite" if LITE_MODE else f"{username}/items_full"

train, val, test = Item.from_hub(dataset)
items = train + val + test

print(f"Loaded {len(train):,} training items, {len(val):,} validation items, {len(test):,} test items")
# Out:
# Loaded 20,000 training items, 1,000 validation items, 1,000 test items

# %%
BASE_MODEL = "meta-llama/Llama-3.2-3B"

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]

# %%
token_counts = [item.count_tokens(tokenizer) for item in tqdm(items)]
# Out:
#   0%|          | 0/22000 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(15, 6))
plt.title(f"Tokens in Summary: Avg {sum(token_counts)/len(token_counts):,.1f} and highest {max(token_counts):,}\n")
plt.xlabel('Number of tokens in summary')
plt.ylabel('Count')
plt.hist(token_counts, rwidth=0.7, color="skyblue", bins=range(0, 200, 10))
plt.show()

# %%
CUTOFF = 110
cut = len([count for count in token_counts if count > CUTOFF])
print(f"With this CUTOFF, we will truncate {cut:,} items which is {cut/len(items):.1%}")
# Out:
# With this CUTOFF, we will truncate 1,255 items which is 5.7%

# %%
print(train[0].summary)
# Out:
# Title: Schlage F59 & 613 Andover Interior Knob (Deadbolt Included)
# Category: Home Hardware
# Brand: Schlage
# Description: A single‑piece oil‑rubbed bronze knob that mounts to a deadbolt for secure, easy interior door use.
# Details: Designed for a 4" minimum center‑to‑center door prep, it offers a lifetime mechanical and finish warranty and comes ready for quick installation.

# %%
for item in tqdm(train+val):
    item.make_prompts(tokenizer, CUTOFF, True)
for item in tqdm(test):
    item.make_prompts(tokenizer, CUTOFF, False)
# Out:
#   0%|          | 0/21000 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
print("PROMPT:")
print(test[3].prompt)
print("COMPLETION:")
print(test[3].completion)
# Out:
# PROMPT:
# What does this cost to the nearest dollar?
#
# Title: EXMAX NG-10X Fresnel Lens Focusing Adapter
# Category: Lighting Accessories
# Brand: EXMAX
# Description: A telescoping Bowens‑mount adapter that concentrates LED studio light into a 10–40° spot, boosting brightness 5–10× and offering quick color filter swaps.
# Details: Features a durable black plastic construction, adjustable focus, integrated four‑color gel filters, and compatibility with most LED or flash lights up to 150 W.
#
# Price is $
# COMPLETION:
# 69.98

# %%
print("PROMPT:")
print(train[3].prompt)
print("COMPLETION:")
print(train[3].completion)
# Out:
# PROMPT:
# What does this cost to the nearest dollar?
#
# Title: Hollyland Mars 300 Pro Wireless Video Transmitter & Receiver
# Category: Electronics
# Brand: Hollyland
# Description: A 1080p HDMI wireless system with 300ft range, 0.08s latency, and built‑in OLED controls.
# Details: Includes dual HDMI input/output, app monitoring, smart channel selection, and a free battery pack with AC charger.
#
# Price is $
# COMPLETION:
# 449.00

# %%
prompt_token_counts = [item.count_prompt_tokens(tokenizer) for item in tqdm(items)]
# Out:
#   0%|          | 0/22000 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(15, 6))
plt.title(f"Tokens: Avg {sum(prompt_token_counts)/len(prompt_token_counts):,.1f} and highest {max(prompt_token_counts):,}\n")
plt.xlabel('Number of tokens in prompt and the completion')
plt.ylabel('Count')
plt.hist(prompt_token_counts, rwidth=0.7, color="gold", bins=range(0, 200, 10))
plt.show()

# %%
username = "ed-donner"
dataset = f"{username}/items_prompts_lite" if LITE_MODE else f"{username}/items_prompts_full"

Item.push_prompts_to_hub(dataset, train, val, test)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/20 [00:00<?, ?ba/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:402, in hf_raise_for_status(response, endpoint_name)
#     401 try:
# --> 402     response.raise_for_status()
#     403 except HTTPError as e:
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/datasets/ed-donner/items_prompts_lite.git/info/lfs/objects/batch
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[20], line 4
#       1 username = "ed-donner"
#       2 dataset = f"{username}/items_prompts_lite" if LITE_MODE else f"{username}/items_prompts_full"
# ----> 4 Item.push_prompts_to_hub(dataset, train, val, test)
#
# File ~/Desktop/llm-engineering-course/llm_engineering/week7/pricer/items.py:89, in Item.push_prompts_to_hub(dataset_name, train, val, test)
#      78 @staticmethod
#      79 def push_prompts_to_hub(
#      80     dataset_name: str, train: list[Self], val: list[Self], test: list[Self]
#      81 ):
#      82     """Push Item lists to HuggingFace Hub in prompt-completion format for SFT training."""
#      83     DatasetDict(
#      84         {
#      85             "train": Dataset.from_list([item.to_datapoint() for item in train]),
#      86             "val": Dataset.from_list([item.to_datapoint() for item in val]),
#      87             "test": Dataset.from_list([item.to_datapoint() for item in test]),
#      88         }
# ---> 89     ).push_to_hub(dataset_name)
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/datasets/dataset_dict.py:1749, in DatasetDict.push_to_hub(self, repo_id, config_name, set_default, data_dir, commit_message, commit_description, private, token, revision, create_pr, max_shard_size, num_shards, embed_external_files)
#    1747 logger.info(f"Pushing split {split} to the Hub.")
#    1748 # The split=key needs to be removed before merging
# -> 1749 split_additions, uploaded_size, dataset_nbytes = self[split]._push_parquet_shards_to_hub(
#    1750     repo_id,
#    1751     data_dir=data_dir,
#    1752     split=split,
#    1753     token=token,
#    1754     revision=revision,
#    1755     create_pr=create_pr,
#    1756     max_shard_size=max_shard_size,
#    1757     num_shards=num_shards.get(split),
#    1758     embed_external_files=embed_external_files,
#    1759 )
#    1760 additions += split_additions
#    1761 total_uploaded_size += uploaded_size
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/datasets/arrow_dataset.py:5401, in Dataset._push_parquet_shards_to_hub(self, repo_id, data_dir, split, token, revision, create_pr, max_shard_size, num_shards, embed_external_files)
#    5399     del buffer
#    5400     shard_addition = CommitOperationAdd(path_in_repo=shard_path_in_repo, path_or_fileobj=parquet_content)
# -> 5401     api.preupload_lfs_files(
#    5402         repo_id=repo_id,
#    5403         additions=[shard_addition],
#    5404         repo_type="dataset",
#    5405         revision=revision,
#    5406         create_pr=create_pr,
#    5407     )
#    5408     additions.append(shard_addition)
#    5410 return additions, uploaded_size, dataset_nbytes
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/hf_api.py:4494, in HfApi.preupload_lfs_files(self, repo_id, additions, token, repo_type, revision, create_pr, num_threads, free_memory, gitignore_content)
#    4482 # Prepare upload parameters
#    4483 upload_kwargs = {
#    4484     "additions": new_lfs_additions_to_upload,
#    4485     "repo_type": repo_type,
#    (...)   4492     "revision": revision if not create_pr else None,
#    4493 }
# -> 4494 _upload_files(**upload_kwargs, num_threads=num_threads, create_pr=create_pr)  # type: ignore [arg-type]
#    4495 for addition in new_lfs_additions_to_upload:
#    4496     addition._is_uploaded = True
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/_commit_api.py:389, in _upload_files(additions, repo_type, repo_id, headers, endpoint, num_threads, revision, create_pr)
#     383     else:
#     384         logger.warning(
#     385             "Uploading files as a binary IO buffer is not supported by Xet Storage. "
#     386             "Falling back to HTTP upload."
#     387         )
# --> 389 actions_chunk, errors_chunk, chosen_transfer = post_lfs_batch_info(
#     390     upload_infos=[op.upload_info for op in chunk_list],
#     391     repo_id=repo_id,
#     392     repo_type=repo_type,
#     393     revision=revision,
#     394     endpoint=endpoint,
#     395     headers=headers,
#     396     token=None,  # already passed in 'headers'
#     397     transfers=transfers,
#     398 )
#     399 if errors_chunk:
#     400     message = "\n".join(
#     401         [
#     402             f"Encountered error for file with OID {err.get('oid')}: `{err.get('error', {}).get('message')}"
#     403             for err in errors_chunk
#     404         ]
#     405     )
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/lfs.py:172, in post_lfs_batch_info(upload_infos, token, repo_type, repo_id, revision, endpoint, headers, transfers)
#     166 headers = {
#     167     **LFS_HEADERS,
#     168     **build_hf_headers(token=token),
#     169     **(headers or {}),
#     170 }
#     171 resp = get_session().post(batch_url, headers=headers, json=payload)
# --> 172 hf_raise_for_status(resp)
#     173 batch_info = resp.json()
#     175 objects = batch_info.get("objects", None)
#
# File ~/Desktop/llm-engineering-course/llm_engineering/.venv/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:466, in hf_raise_for_status(response, endpoint_name)
#     460 elif response.status_code == 403:
#     461     message = (
#     462         f"\n\n{response.status_code} Forbidden: {error_message}."
#     463         + f"\nCannot access content at: {response.url}."
#     464         + "\nMake sure your token has the correct permissions."
#     465     )
# --> 466     raise _format(HfHubHTTPError, message, response) from e
#     468 elif response.status_code == 416:
#     469     range_header = response.request.headers.get("Range")
#
# HfHubHTTPError: (Request ID: Root=1-696d5613-5a05873c5e08c1e628fc9bcc;42edcbff-4a21-4a02-93a1-16b17d94f846)
#
# 403 Forbidden: You have read access but not the required permissions for this operation.
# Cannot access content at: https://huggingface.co/datasets/ed-donner/items_prompts_lite.git/info/lfs/objects/batch.
# Make sure your token has the correct permissions.

# %% [markdown]
# Here are the datasets in HuggingFace:
#
# https://huggingface.co/datasets/ed-donner/items_prompts_lite
#
# https://huggingface.co/datasets/ed-donner/items_prompts_full
#
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1wO3lNMrMfprlJZF4X9fSsQ8tYC3SRZbh?usp=sharing
